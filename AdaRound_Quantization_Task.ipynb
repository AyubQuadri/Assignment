# %% [markdown]
# <a href="https://colab.research.google.com/github/AyubQuadri/Assignment/blob/main/AdaRound_Quantization_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/yhhhli/BRECQ.git
# !kaggle datasets download -d ifigotin/imagenetmini-1000
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ifigotin/imagenetmini-1000
# License(s): unknown
# ...
# 100% 3.92G/3.92G [02:36<00:00, 26.5MB/s]
# 100% 3.92G/3.92G [02:36<00:00, 27.0MB/s]

# %%
# !unzip imagenetmini-1000.zip
# !mv imagenet-mini BRECQ/data/

# %%
# %cd BRECQ/
# Out:
# /content/drive/MyDrive/BRECQ

# %%
# !python main_imagenet.py --data_path ./data/imagenet-mini/ --arch resnet18 --n_bits_w 2 --channel_wise --n_bits_a 4 --act_quant --test_before_calibration
# Out:
# You are using fake SyncBatchNorm2d who is actually the official BatchNorm2d
# ==> Using Pytorch Dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Downloading: "https://github.com/yhhhli/BRECQ/releases/download/v1.0/resnet18_imagenet.pth.tar" to /root/.cache/torch/hub/checkpoints/resnet18_imagenet.pth.tar
# 100% 44.6M/44.6M [00:01<00:00, 41.1MB/s]
# Setting the first and the last layer to 8-bit
# Test: [ 0/62]	Time  4.637 ( 4.637)	Acc@1   0.00 (  0.00)	Acc@5   0.00 (  0.00)
#  * Acc@1 0.025 Acc@5 0.535
# ...
